# %% [markdown]
# <a href="https://colab.research.google.com/github/superpoupette/data-tab/blob/main/notebooks/01_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys

sys.version

# %%
from scripts.importation_hevy import prepare_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from scripts.importation_hevy import prepare_data
#
# ModuleNotFoundError: No module named 'scripts'

# %%
# !git clone https://github.com/superpoupette/data-tab.git

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
os.chdir("/content/data-tab")

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	data-tab/
# 	scripts/__pycache__/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 3.81 KiB | 1.90 MiB/s, done.
# From https://github.com/superpoupette/data-tab
#    66cf0b6..4afc020  main       -> origin/main
# Updating 66cf0b6..4afc020
# Fast-forward
#  notebooks/01_exploration.ipynb | 737 ++++++-----------------------------------
#  1 file changed, 110 insertions(+), 627 deletions(-)

# %%
import importlib
import scripts.importation_hevy as ih

importlib.reload(ih)

# %%
from scripts.importation_hevy import prepare_data

# %%
workouts, sessions = prepare_data(
    "data/workouts.csv",
    "data/exercices.csv"
)

# %%
sessions.head()

# %%
workouts.head()

# %%
import matplotlib.pyplot as plt

# Compter le nombre de séances par mois
sessions_par_mois = sessions.groupby("mois").size()

# Création du graphique
plt.figure(figsize=(12, 5))

plt.bar(
    sessions_par_mois.index.astype(str),
    sessions_par_mois.values
)

plt.xlabel("Mois")
plt.ylabel("Nombre de séances")
plt.title("Nombre de séances par mois")

plt.xticks(rotation=45)

plt.show()

# %%
import matplotlib.pyplot as plt

# Somme du temps d'entraînement par mois
temps_par_mois = sessions.groupby("mois")["duree_minutes"].sum()

# Création du graphique
plt.figure(figsize=(12, 5))

plt.bar(
    temps_par_mois.index.astype(str),
    temps_par_mois.values
)

plt.xlabel("Mois")
plt.ylabel("Temps d'entraînement (minutes)")
plt.title("Temps total d'entraînement par mois")

plt.xticks(rotation=45)

plt.show()

# %%
import matplotlib.pyplot as plt

# Somme du temps du volume par mois
volume_par_mois = sessions.groupby("mois")["volume_total"].sum()

# Création du graphique
plt.figure(figsize=(12, 5))

plt.bar(
    volume_par_mois.index.astype(str),
    volume_par_mois.values
)

plt.xlabel("Mois")
plt.ylabel("Volume d'entraînement (kg)")
plt.title("Volume total d'entraînement par mois")

plt.xticks(rotation=45)

plt.show()

# %%
import matplotlib.pyplot as plt

# Nombre d'exercices par groupe musculaire
repartition = workouts["muscle"].value_counts()

# Diagramme en camembert
plt.figure(figsize=(7, 7))

plt.pie(
    repartition,
    labels=repartition.index,
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Répartition des exercices par groupe musculaire")

plt.show()

# %%
print(f"Nombre total de séances : {len(sessions)}")

print(f"Temps total : {sessions['duree_minutes'].sum()/60:.1f} h")

print(f"Volume total : {workouts['volume'].sum()/1000:.1f} tonnes")

print(f"Exercices différents : {workouts['exercise_title'].nunique()}")

print(f"Durée moyenne : {sessions['duree_minutes'].mean():.0f} min")

# %%
import importlib
import scripts.importation_babelio as ib

importlib.reload(ib)

from scripts.importation_babelio import prepare_babelio

# %%
# !head -5 data/biblio.csv
# Out:
# "ISBN";"Titre";"Auteur";"Editeur";"Date de publication";"Date d`entr�e dans Babelio";"Statut";"Note"
# "9782493909213";"Mon mari";"Ventura Maud";"Collection Proche";"2023-05-11";"2026-06-15 20:39:16";"Lu";"3.5"
# "9782072824425";"Vers la beaut�";"Foenkinos David";"Folio";"2019-05-02";"2026-06-02 13:07:09";"Lu";"3.0"
# "9791041420216";"Monique s'�vade";"Louis �douard";"Points";"2025-04-25";"2026-05-01 17:50:10";"En cours";"4.5"
# "9782253251033";"La Derni�re Allumette";"Vareille Marie";"Le Livre de Poche";"2025-04-02";"2026-04-05 21:05:54";"Lu";"4.5"

# %%
livres = prepare_babelio(
    "data/biblio.csv"
)

# %%
livres.head()
# Out:
#             ISBN                                            Titre  \
# 0  9782493909213                                         Mon mari
# 1  9782072824425                                   Vers la beauté
# 2  9791041420216                                  Monique s'évade
# 3  9782253251033                            La Dernière Allumette
# 4  9782290026694  La chronique des Bridgerton, tome 6 : Francesca
#
#             Auteur            Editeur Date de publication  \
# 0     Ventura Maud  Collection Proche          2023-05-11
# 1  Foenkinos David              Folio          2019-05-02
# 2    Louis Édouard             Points          2025-04-25
# 3   Vareille Marie  Le Livre de Poche          2025-04-02
# 4      Quinn Julia            J'ai lu          2010-09-15
#
#   Date d`entrée dans Babelio    Statut  Note
# 0        2026-06-15 20:39:16        Lu   3.5
# 1        2026-06-02 13:07:09        Lu   3.0
# 2        2026-05-01 17:50:10  En cours   4.5
# 3        2026-04-05 21:05:54        Lu   4.5
# 4        2026-04-05 21:04:19        Lu   3.5

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Conversion de la date d'entrée
livres["date_entree"] = pd.to_datetime(livres["Date d`entrée dans Babelio"])

# Création du mois
livres["mois"] = livres["date_entree"].dt.to_period("M")

# Nombre de livres par mois
livres_par_mois = livres.groupby("mois").size()

# Graphique
plt.figure(figsize=(10, 5))

plt.bar(
    livres_par_mois.index.astype(str),
    livres_par_mois.values
)

plt.xlabel("Mois")
plt.ylabel("Nombre de livres")
plt.title("Nombre de livres ajoutés par mois")

plt.xticks(rotation=45)

plt.show()
